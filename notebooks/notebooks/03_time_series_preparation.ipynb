# %% [markdown]
# # Time Series Preparation for Demand Forecasting

# %%
# %pip install statsmodels
# Out:
# Requirement already satisfied: statsmodels in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (0.14.6)
# Requirement already satisfied: numpy<3,>=1.22.3 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from statsmodels) (1.26.4)
# Requirement already satisfied: scipy!=1.9.2,>=1.8 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from statsmodels) (1.16.3)
# Requirement already satisfied: pandas!=2.1.0,>=1.4 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from statsmodels) (3.0.0)
# Requirement already satisfied: patsy>=0.5.6 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from statsmodels) (1.0.2)
# Requirement already satisfied: packaging>=21.3 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from statsmodels) (25.0)
# Requirement already satisfied: python-dateutil>=2.8.2 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2.9.0.post0)
# Requirement already satisfied: tzdata in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from pandas!=2.1.0,>=1.4->statsmodels) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\Users\APOORV\AppData\Local\Programs\Python\Python311\Lib\site-packages (from python-dateutil>=2.8.2->pandas!=2.1.0,>=1.4->statsmodels) (1.17.0)
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 26.0.1 -> 26.1.2
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose

import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# #### Load dataset

# %%
df = pd.read_csv("../../data/cleaned/cleaned_retail.csv")

# %% [markdown]
# #### Preprocessing

# %%
df["InvoiceDate"] = pd.to_datetime(df["InvoiceDate"])

# %% [markdown]
# #### Daily Sales Aggregation

# %%
sales = (
    df.groupby("InvoiceDate")["TotalPrice"]
    .sum()
    .reset_index()
)

sales.columns = ["ds", "y"]

sales.head()
# Out:
#                    ds       y
# 0 2010-12-01 08:26:00  139.12
# 1 2010-12-01 08:28:00   22.20
# 2 2010-12-01 08:34:00  348.78
# 3 2010-12-01 08:35:00   17.85
# 4 2010-12-01 08:45:00  855.86

# %% [markdown]
# #### Basic Dataset Check

# %%
print("Shape:", sales.shape)

sales.info()
# Out:
# Shape: (17282, 2)
# <class 'pandas.DataFrame'>
# RangeIndex: 17282 entries, 0 to 17281
# Data columns (total 2 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   ds      17282 non-null  datetime64[us]
#  1   y       17282 non-null  float64
# dtypes: datetime64[us](1), float64(1)
# memory usage: 270.2 KB

# %% [markdown]
# #### Time Series Visualization

# %%
plt.figure(figsize=(12,5))

plt.plot(sales["ds"], sales["y"])

plt.title("Daily Revenue Time Series")
plt.xlabel("Date")
plt.ylabel("Revenue")

plt.show()

# %% [markdown]
# #### Stationarity Test

# %%
result = adfuller(sales["y"])

print("ADF Statistic:", result[0])
print("p-value:", result[1])
print("Critical Values:")

for key, value in result[4].items():
    print(f"{key}: {value}")
# Out:
# ADF Statistic: -128.8621281153383
# p-value: 0.0
# Critical Values:
# 1%: -3.430728466039107
# 5%: -2.8617072672381836
# 10%: -2.566859032032201

# %%
if result[1] < 0.05:
    print("The time series is stationary.")
else:
    print("The time series is non-stationary.")
# Out:
# The time series is stationary.

# %% [markdown]
# #### Time Series Decomposition

# %%
sales_ts = sales.set_index("ds")

decomposition = seasonal_decompose(
    sales_ts["y"],
    model="additive",
    period=30
)

# %% [markdown]
# #### Plot Decomposition

# %%
fig, axes = plt.subplots(4, 1, figsize=(12, 8), sharex=True)

axes[0].plot(decomposition.observed)
axes[0].set_ylabel("Observed")

axes[1].plot(decomposition.trend)
axes[1].set_ylabel("Trend")

axes[2].plot(decomposition.seasonal)
axes[2].set_ylabel("Seasonal")

axes[3].plot(decomposition.resid)
axes[3].set_ylabel("Residual")

plt.tight_layout()
plt.show()

# %% [markdown]
# #### ADF Test Results
#
# The Augmented Dickey-Fuller (ADF) test produced an ADF statistic of -128.86 and a p-value of 0.0.
#
# Since the p-value is less than 0.05, the null hypothesis of non-stationarity is rejected. This indicates that the sales time series is stationary and suitable for forecasting analysis.

# %% [markdown]
# #### Save Prepared Time Series

# %%
sales.to_csv(
    "../../data/cleaned/time_series_data.csv",
    index=False
)
